# %%
import pandas as pd
import os

# %%
data= pd.read_csv("Desktop/DATA TYPES/Binance_BTCUSDT_2020_minute.csv")

# %%
data.head()
# Out:
#             unix                 date    symbol      open      high       low  \
# 0  1609459140000  2020-12-31 23:59:00  BTC/USDT  28923.66  28952.28  28903.86
# 1  1609459080000  2020-12-31 23:58:00  BTC/USDT  28975.03  28977.10  28923.15
# 2  1609459020000  2020-12-31 23:57:00  BTC/USDT  28975.06  28981.41  28955.35
# 3  1609458960000  2020-12-31 23:56:00  BTC/USDT  28978.91  28988.06  28969.99
# 4  1609458900000  2020-12-31 23:55:00  BTC/USDT  28977.83  28983.62  28956.76
#
#       close  Volume BTC   Volume USDT  tradecount
# 0  28923.63   51.895343  1.501321e+06         860
# 1  28923.67   36.070975  1.044267e+06         615
# 2  28975.03   21.327772  6.178355e+05         564
# 3  28975.06   19.086172  5.530618e+05         570
# 4  28979.72   15.936455  4.616632e+05         603

# %%
data.tail()
# Out:
#                  unix                 date    symbol     open     high  \
# 526684  1577837100000  2020-01-01 00:05:00  BTC/USDT  7174.71  7177.14
# 526685  1577837040000  2020-01-01 00:04:00  BTC/USDT  7179.10  7179.10
# 526686  1577836980000  2020-01-01 00:03:00  BTC/USDT  7177.77  7182.60
# 526687  1577836920000  2020-01-01 00:02:00  BTC/USDT  7179.01  7179.01
# 526688  1577836860000  2020-01-01 00:01:00  BTC/USDT  7182.43  7182.44
#
#             low    close  Volume BTC   Volume USDT  tradecount
# 526684  7173.28  7175.61      33.725  241979.50880         124
# 526685  7172.94  7175.25      97.368  698627.39382         193
# 526686  7177.00  7181.11      69.330  497793.35929         104
# 526687  7175.25  7177.93      99.420  713539.55348         148
# 526688  7178.75  7179.01      70.909  509145.78482         140

# %%
data.shape
# Out:
# (526689, 10)
